# %%
import os
import numpy as np
import pandas as pd
import pickle
import json
import quandl
from pathlib import Path
from datetime import datetime
from dotenv import load_dotenv
load_dotenv()

# %matplotlib inline

# %%
import panel as pn
pn.extension('plotly')
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.express as px
import plotly.graph_objs as go
import plotly.figure_factory as ff
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
quandl.ApiConfig.api_key = os.environ['QUANDL_API_KEY']

# %%
# Pull Kraken BTC price exchange data with desired date range, and return it as a DF
kraken_btc_df = quandl.get('BCHARTS/KRAKENUSD', start_date='2019-01-01', end_date='2021-06-30', returns='DataFrame')
kraken_btc_df
# Out:
#                Open     High      Low    Close  Volume (BTC)  \
# Date
# 2019-01-01   3690.9   4499.3   3643.7   3820.1   5422.737692
# 2019-01-02   3825.0   3920.0   3767.2   3886.2   5737.248428
# 2019-01-03   3887.8   3895.5   3721.9   3786.5   5533.988728
# 2019-01-04   3785.3   3856.9   3728.8   3823.7   5078.832023
# 2019-01-05   3823.6   3874.7   3772.1   3796.6   3545.082095
# ...             ...      ...      ...      ...           ...
# 2021-06-16  40167.3  40493.0  38120.0  38337.1   6487.206888
# 2021-06-17  38337.1  39561.4  37405.0  38078.2   6003.220618
# 2021-06-18  38078.2  38193.1  35126.0  35824.0   6558.468890
# 2021-06-19  35824.0  36450.0  34901.0  35490.5   4485.076656
# 2021-06-20  35484.2  36112.2  33370.0  35668.7   6229.513564
#
#             Volume (Currency)  Weighted Price
# Date
# 2019-01-01       2.053113e+07     3786.119798
# 2019-01-02       2.205424e+07     3844.045380
# 2019-01-03       2.115354e+07     3822.476548
# 2019-01-04       1.923637e+07     3787.557313
# 2019-01-05       1.359609e+07     3835.198311
# ...                       ...             ...
# 2021-06-16       2.539206e+08    39141.737747
# 2021-06-17       2.307246e+08    38433.468618
# 2021-06-18       2.409217e+08    36734.445103
# 2021-06-19       1.603145e+08    35743.971502
# 2021-06-20       2.168125e+08    34804.086189
#
# [893 rows x 7 columns]

# %%
#Making a df with only Dates and Closing Prices
kraken_btc_close = kraken_btc_df.drop(columns=['Open', 'High', 'Low', 'Volume (BTC)', 'Volume (Currency)', 'Weighted Price'])     
kraken_btc_close.head()
# Out:
#              Close
# Date
# 2019-01-01  3820.1
# 2019-01-02  3886.2
# 2019-01-03  3786.5
# 2019-01-04  3823.7
# 2019-01-05  3796.6

# %%
#Making another DF with Weighted Prices for later comparisons
kraken_btc_wprice = kraken_btc_df.drop(columns=['Open', 'High', 'Low', 'Volume (BTC)', 'Volume (Currency)'])
kraken_btc_wprice.head()
# Out:
#              Close  Weighted Price
# Date
# 2019-01-01  3820.1     3786.119798
# 2019-01-02  3886.2     3844.045380
# 2019-01-03  3786.5     3822.476548
# 2019-01-04  3823.7     3787.557313
# 2019-01-05  3796.6     3835.198311

# %%
#Create a DF to with the BTC and USD volumes, also for possible later comparison
kraken_btc_usd_volume =  kraken_btc_df.drop(columns=['Open', 'High','Close', 'Low', 'Weighted Price'])
kraken_btc_usd_volume.head()
# Out:
#             Volume (BTC)  Volume (Currency)
# Date
# 2019-01-01   5422.737692       2.053113e+07
# 2019-01-02   5737.248428       2.205424e+07
# 2019-01-03   5533.988728       2.115354e+07
# 2019-01-04   5078.832023       1.923637e+07
# 2019-01-05   3545.082095       1.359609e+07

# %%
#Run pct_change BTC price df's to get return dfs
btc_close_returns = kraken_btc_close.pct_change()
btc_weighted_returns= kraken_btc_wprice.pct_change()

# %%
#Plotting Daily Returns from Close prices
btc_close_returns_fig = px.line(btc_close_returns,title = 'BTC/USD Daily Returns')
btc_close_returns_fig.show()

# %%
#Plotting Daily returns from Weighted Prices
btc_weighted_returns_fig = px.line(btc_weighted_returns, title = 'BTC/USD Daily Returns based on Weighted Prices' )
btc_weighted_returns_fig.show()

# %%
#Comparison of BTC Volume to USD Volume
btc_usd_vol_fig = px.line(kraken_btc_usd_volume,title = 'BTC & USD Volume')
btc_usd_vol_fig.show()

# %%
#Pulling API from Quandl that has 90 rolling Correlation for BTC w/ GLD, TW-USD, NASDAQ US Lrg Cap index and Nasdaq EURO 50 index 
btc_correlate = quandl.get('BIC/COR', start_date='2019-01-01', end_date='2021-06-30', returns='DataFrame')
btc_correlate
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-10-7b88b43d979f> in <module>
#       1 #Pulling API from Quandl that has 90 rolling Correlation for BTC w/ GLD, TW-USD, NASDAQ US Lrg Cap index and Nasdaq EURO 50 index
# ----> 2 btc_correlate = quandl.get('BIC/COR', start_date='2019-01-01', end_date='2021-06-30', returns='DataFrame')
#       3 btc_correlate
#
# ~\anaconda3\envs\crypto-anal\lib\site-packages\quandl\get.py in get(dataset, **kwargs)
#      46         if dataset_args['column_index'] is not None:
#      47             kwargs.update({'column_index': dataset_args['column_index']})
# ---> 48         data = Dataset(dataset_args['code']).data(params=kwargs, handle_column_not_found=True)
#      49     # Array
#      50     elif isinstance(dataset, list):
#
# ~\anaconda3\envs\crypto-anal\lib\site-packages\quandl\model\dataset.py in data(self, **options)
#      45         updated_options = Util.merge_options('params', params, **options)
#      46         try:
# ---> 47             return Data.all(**updated_options)
#      48         except NotFoundError:
#      49             if handle_not_found_error:
#
# ~\anaconda3\envs\crypto-anal\lib\site-packages\quandl\operations\list.py in all(cls, **options)
#      13             options['params'] = {}
#      14         path = Util.constructed_path(cls.list_path(), options['params'])
# ---> 15         r = Connection.request('get', path, **options)
#      16         response_data = r.json()
#      17         Util.convert_to_dates(response_data)
#
# ~\anaconda3\envs\crypto-anal\lib\site-packages\quandl\connection.py in request(cls, http_verb, url, **options)
#      36         abs_url = '%s/%s' % (ApiConfig.api_base, url)
#      37
# ---> 38         return cls.execute_request(http_verb, abs_url, **options)
#      39
#      40     @classmethod
#
# ~\anaconda3\envs\crypto-anal\lib\site-packages\quandl\connection.py in execute_request(cls, http_verb, url, **options)
#      48                                        **options)
#      49             if response.status_code < 200 or response.status_code >= 300:
# ---> 50                 cls.handle_api_error(response)
#      51             else:
#      52                 return response
#
# ~\anaconda3\envs\crypto-anal\lib\site-packages\quandl\connection.py in handle_api_error(cls, resp)
#     112         klass = d_klass.get(code_letter, QuandlError)
#     113
# --> 114         raise klass(message, resp.status_code, resp.text, resp.headers, code)
#
# NotFoundError: (Status 404) (Quandl Error QECx02) You have submitted an incorrect Quandl code. Please check your Quandl codes and try again.
